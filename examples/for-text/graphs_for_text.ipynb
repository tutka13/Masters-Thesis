# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import math
#from matplotlib.patches import Rectangle

# %%
# Define the colormap transitioning from red to blue
colors = [(0, 0, 0), (0, 0, 1)]
cmap = mcolors.LinearSegmentedColormap.from_list('my_colormap', colors)

# %%
# Create the data
axlimx = 2.1
axlimy = 2.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

# Latex style in text
plt.rcParams['text.usetex'] = True

# %%
axlimx = 2.1
axlimy = 2.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(-1,1,0.1):
    Fxy =  Y - 2*X*t + t**2
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

Exy = Y - X**2
plt.contour(X, Y, Exy, levels=[0], colors='black', linewidth=2)
plt.gca().set_aspect('equal')
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.title(r'$F(x, y, t) = y - 2xt + t^2$', fontsize='12')

plt.savefig("C:\\Users\\tutko\\Desktop\\images\\odr.pdf")
# Out:
# C:\Users\tutko\AppData\Local\Temp\ipykernel_20548\2809007142.py:12: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(X, Y, Exy, levels=[0], colors='black', linewidth=2)
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\tutko\Desktop\Masters-Thesis\examples\for-text\graphs_for_text.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/tutko/Desktop/Masters-Thesis/examples/for-text/graphs_for_text.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> plt.ylabel('$y$', fontsize='12')
#      <a href='vscode-notebook-cell:/c%3A/Users/tutko/Desktop/Masters-Thesis/examples/for-text/graphs_for_text.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> plt.title(r'$F(x, y, t) = y - 2xt + t^2$', fontsize='12')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tutko/Desktop/Masters-Thesis/examples/for-text/graphs_for_text.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> plt.savefig("C:\\Users\\tutko\\Desktop\\images\\odr.pdf")
#
# File c:\Python311\Lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File c:\Python311\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:2187, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2183 try:
#    2184     # _get_renderer may change the figure dpi (as vector formats
#    2185     # force the figure dpi to 72), so we need to set it again here.
#    2186     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2187         result = print_method(
#    2188             filename,
#    2189             facecolor=facecolor,
#    2190             edgecolor=edgecolor,
#    2191             orientation=orientation,
#    2192             bbox_inches_restore=_bbox_inches_restore,
#    2193             **kwargs)
#    2194 finally:
#    2195     if bbox_inches and restore_bbox:
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File c:\Python311\Lib\site-packages\matplotlib\backends\backend_pdf.py:2800, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2798     file = filename._ensure_file()
#    2799 else:
# -> 2800     file = PdfFile(filename, metadata=metadata)
#    2801 try:
#    2802     file.newPage(width, height)
#
# File c:\Python311\Lib\site-packages\matplotlib\backends\backend_pdf.py:688, in PdfFile.__init__(self, filename, metadata)
#     686 self.original_file_like = None
#     687 self.tell_base = 0
# --> 688 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     689 if not opened:
#     690     try:
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook.py:483, in to_filehandle(fname, flag, return_opened, encoding)
#     481         fh = bz2.BZ2File(fname, flag)
#     482     else:
# --> 483         fh = open(fname, flag, encoding=encoding)
#     484     opened = True
#     485 elif hasattr(fname, 'seek'):
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\tutko\\Desktop\\images\\odr.pdf'

# %%
# Create the contour plot
axlimx = 5.1
axlimy = 5.1
x = np.linspace(-axlimx, axlimx, 200)
y = np.linspace(-axlimy, axlimy, 200)
X, Y = np.meshgrid(x, y)

#resultant = 191102976*X**(10) + 262144*X**8*Y**6 - 9584640*X**8*Y**4 + 83165184*X**8*Y**2 - 633470976*X**8 - 16384*X**6*Y**(10) - 81920*X**6*Y**8 - 14483456*X**6*Y**6 - 113311744*X**6*Y**4 + 96419840*X**6*Y**2 + 698368000*X**6 - 16384*X**4*Y**(12) - 294912*X**4*Y**(10) - 2998272*X**4*Y**8 - 18284544*X**4*Y**6 - 74956800*X**4*Y**4 - 184320000*X**4*Y**2 - 256000000*X**4
resultant = 191102976*X**10 + 262144*X**8*Y**6 - 9584640*X**8*Y**4 + 83165184*X**8*Y**2 - 633470976*X**8 - 16384*X**6*Y**10 - 81920*X**6*Y**8 - 14483456*X**6*Y**6 - 113311744*X**6*Y**4 + 96419840*X**6*Y**2 + 698368000*X**6 - 16384*X**4*Y**12 - 294912*X**4*Y**10 - 2998272*X**4*Y**8 - 18284544*X**4*Y**6 - 74956800*X**4*Y**4 - 184320000*X**4*Y**2 - 256000000*X**4

for t in np.arange(-2,2,0.1):
    Fxy = X**2/(t**2+1)**2+(Y-2*t)**2-1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+2)/4)])

plt.contour(X, Y, resultant, levels=[0], colors='black', linewidth=2)

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \frac{x^2}{(t^2+1)^2}+(y-2t)^2-1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\resultant.pdf")
# Out:
# C:\Users\tutko\AppData\Local\Temp\ipykernel_20548\3123228550.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(X, Y, resultant, levels=[0], colors='black', linewidth=2)

# %%
# Create the contour plot
axlimx = 5.1
axlimy = 5.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(-2,2,0.1):
    Fxy = X**2/(t**2+1)**2+(Y-2*t)**2-1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+2)/4)])

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \frac{x^2}{(t^2+1)^2}+(y-2t)^2-1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\too_complicated_equations.pdf")

# %%
# Create the contour plot
axlimx = 3.1
axlimy = 3.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(0,2*math.pi,0.12):
    Fxy = X*math.cos(t) + Y*math.sin(t) - 1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap(t/(2*math.pi))])

""" t = 0
Fxy = X*math.cos(t) + Y*math.sin(t) - 1
plt.contour(X, Y, Fxy, levels=[0], colors='lime') """

#t = math.pi/2
#Fxy = X*math.cos(t) + Y*math.sin(t) - 1
#plt.contour(X, Y, Fxy, levels=[0], colors='red')

t = 0.56
Fxy = X*math.cos(t) + Y*math.sin(t) - 1
plt.contour(X, Y, Fxy, levels=[0], colors='black') 

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \cos tx + \sin ty - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\lines_in_normal_form.pdf")

# %%
axlimx = 1.6
axlimy = 1.6
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)
count = 0

# Create the contour plot
for t in np.arange(0.1,2,0.1):
    Fxy = X**2 + Y**2  - t
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t)/2)])
    count +=1

print(count)
# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = x^2 + y^2 - t$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\concentric_circles.pdf")
# Out:
# 19

# %%
axlimx = 2.1
axlimy = 1.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\system.pdf")

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

""" Fxy = (X+1)**2 + Y**2  - 1
plt.contour(X, Y, Fxy, levels=[0], colors='blue') """

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\one_element_of_system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\one_element_of_system.pdf")

# %%
axlimx = 2.1
axlimy = 1.2
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-1.1, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(-0.9,1.1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

Fxy = (X+1)**2 + Y**2  - 1
plt.contour(X, Y, Fxy, levels=[0], colors='blue')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')
plt.text(-1.3, 1.05, f'$t = -1$', fontsize=11, color='blue')
plt.text(0.9, 1.05, f'$t = 1$', fontsize=11, color='black')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\one_element_of_system.pdf")
plt.show()

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

# Create an array of y values, all equal to 1
y1 = np.full(x.shape, 1)

# Create an array of y values, all equal to -1
y2 = np.full(x.shape, -1)

# Mask the y values outside of the desired range
y1_masked = np.where(np.logical_and(x >= -1, x <= 1), y1, np.nan)
y2_masked = np.where(np.logical_and(x >= -1, x <= 1), y2, np.nan)

# Plot the lines
plt.plot(x, y1_masked, label='y = 1', color='black', linewidth=2.5)
plt.plot(x, y2_masked, label='y = -1', color='black', linewidth=2.5)

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_correct_envelope.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\system_with_correct_envelope.pdf")

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

Exy1 = Y - 1
Exy2 = Y + 1
plt.contour(X, Y, Exy1, levels=[0], color='black', linewidth=2.5)
plt.contour(X, Y, Exy2, levels=[0], color='black', linewidth=2.5)

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_envelope_unlimited_domain.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\system_with_envelope_unlimited_domain.pdf")
# Out:
# C:\Users\tutko\AppData\Local\Temp\ipykernel_20548\3336807113.py:8: UserWarning: The following kwargs were not used by contour: 'color', 'linewidth'
#   plt.contour(X, Y, Exy1, levels=[0], color='black', linewidth=2.5)
# C:\Users\tutko\AppData\Local\Temp\ipykernel_20548\3336807113.py:9: UserWarning: The following kwargs were not used by contour: 'color', 'linewidth'
#   plt.contour(X, Y, Exy2, levels=[0], color='black', linewidth=2.5)

# %%
# Define the range for x and y
x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)

# Create the contour plot
for t in np.arange(-0.9, 1, 0.1):
    Fxy = (X - t) ** 2 + Y ** 2 - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

Fxy = (X + 1) ** 2 + Y ** 2 - 1
plt.contour(X, Y, Fxy, levels=[0], colors='blue')
plt.text(-1.5, 1.05, f'$t = -1$', fontsize=11, color='blue')
plt.text(1, 1.05, f'$t = 1$', fontsize=11, color='black')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\one_element_of_system.pdf")
plt.show()

# %%
# Define plot parameters
axlimx = 2.1
axlimy = 2.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

# Plot the contours for different values of t
for t in np.arange(-1, 1, 0.05):
    Fxy = Y - 2 * X * t + t ** 2
    plt.contour(X, Y, Fxy, levels=[0], colors=[cmap((t+1)/2)])

# Plot the contour for the equation Exy
Exy = Y - X ** 2
plt.contour(X, Y, Exy, levels=[0], colors='black', linewidths=2)
plt.text(-2.1, -2.55, f'$t =-1$', fontsize=11, color='red')
plt.text(1.7, -2.55, f'$t = 1$', fontsize=11, color='blue')
# Add rectangles around the text annotations
#plt.gca().add_patch(Rectangle((-2.5, -2.5), 0.6, 0.3, linewidth=1, edgecolor='red', facecolor='none'))
#plt.gca().add_patch(Rectangle((-1.8, -2.5), 0.6, 0.3, linewidth=1, edgecolor='blue', facecolor='none'))

# Set plot properties
plt.gca().set_aspect('equal')
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.title(r'$F(x, y, t) = y - 2xt + t^2$', fontsize='12')

# Save the plot as a PDF file
plt.savefig("C:\\Users\\tutko\\Desktop\\images\\odr1.pdf")
plt.show()
